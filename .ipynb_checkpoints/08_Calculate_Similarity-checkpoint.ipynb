# %%
from gensim import corpora, models, similarities
import pandas as pd
import tqdm
import logging

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# load gensim output
dictionary = corpora.Dictionary.load('gensim/dictionary.dict')
corpus = corpora.MmCorpus('gensim/corpus_tfidf.mm')
lsi = models.LsiModel.load('gensim/model.lsi')
index = similarities.MatrixSimilarity.load('gensim/tfidf_lsi_similarities.index')

# %%
# load podcast data
podcast_data = pd.read_pickle('gensim/preprocessed_text_v2.pkl')
podcast_data.shape
# Out:
# (5804, 3)

# %%
podcast_data = podcast_data.reset_index()
del(podcast_data['index'])
podcast_data.head()
# Out:
#       id language                                               text
# 0  16392  English  [host, review, favorit, favorit, classic, pro,...
# 1  18489  English  [everyon, need, hope, everyon, need, encourag,...
# 2  12350  English  [insur, news, interview, rate, announc, insur,...
# 3  12351  English  [amovetv, crew, talk, video, game, esport, lot...
# 4  12352  English  [pastor, greg, lauri, thirtyminut, daili, radi...

# %%
podcast_data.to_pickle('gensim/preprocessed_text_v3.pkl')

# %%
podcast_ids = podcast_data.copy(deep=True)
del(podcast_ids['language'])
del(podcast_ids['text'])

# %%
podcast_ids.to_pickle('gensim/podcast_id_to_gensim_id.pkl')

# %%
podcast_ids = pd.read_pickle('gensim/podcast_id_to_gensim_id.pkl')

# %%
podcast_ids.head()
# Out:
#    podcast_id
# 0       16392
# 1       18489
# 2       12350
# 3       12351
# 4       12352

# %%
podcast_id = 17233
row_id = podcast_data[podcast_data['id'] == podcast_id].index
row_id = row_id[0]

# %%
search_vec = lsi[corpus[row_id]]
sims = index[search_vec]
sims = sorted(enumerate(sims), key=lambda item: -item[1])

# %%
match_ids = [x[0] for x in sims]

# %%
sim_df = pd.DataFrame({"id" : [x[0] for x in sims],
                      "similarity" : [x[1] for x in sims]})
sim_df.head()
# Out:
#      id  similarity
# 0  1634    1.000000
# 1  2904    0.820921
# 2  3862    0.809803
# 3  1804    0.803452
# 4  4191    0.800901

# %%
ids = list(sim_df['id'].values)
len(ids)
# Out:
# 5804

# %%
# Out:
# 5804

# %%
test = [str(x) for x in ids]
test
# Out:
# ['1634',
#  '2904',
#  '3862',
#  '1804',
#  '4191',
#  '1036',
#  '2278',
#  '4507',
#  '7',
#  '3581',
#  '3533',
#  '5425',
#  '3364',
#  '5347',
#  '5130',
#  '891',
#  '2310',
#  '2498',
#  '475',
#  '1052',
#  '4285',
#  '4081',
#  '1172',
#  '1971',
#  '3518',
#  '1518',
#  '5636',
#  '1628',
#  '5311',
#  '916',
#  '1590',
#  '4786',
#  '2663',
#  '5411',
#  '1629',
#  '4258',
#  '3313',
#  '3772',
#  '3019',
#  '2619',
#  '1595',
#  '660',
#  '5419',
#  '3937',
#  '2006',
#  '628',
#  '45',
#  '2075',
#  '5485',
#  '752',
#  '1621',
#  '3049',
#  '5569',
#  '1898',
#  '2510',
#  '4720',
#  '5427',
#  '91',
#  '1088',
#  '4259',
#  '735',
#  '1311',
#  '2579',
#  '165',
#  '3441',
#  '3178',
#  '141',
#  '3860',
#  '2899',
#  '3991',
#  '1359',
#  '5355',
#  '4647',
#  '3580',
#  '5707',
#  '3338',
#  '190',
#  '1627',
#  '689',
#  '2729',
#  '3467',
#  '8',
#  '3863',
#  '765',
#  '5457',
#  '623',
#  '4138',
#  '4210',
#  '4733',
#  '9',
#  '661',
#  '626',
#  '2071',
#  '3707',
#  '4057',
#  '4566',
#  '2933',
#  '3578',
#  '3560',
#  '3047',
#  '1636',
#  '4580',
#  '1984',
#  '5372',
#  '3541',
#  '2523',
#  '5127',
#  '4444',
#  '482',
#  '926',
#  '244',
#  '913',
#  '1635',
#  '4646',
#  '3442',
#  '2905',
#  '13',
#  '1056',
#  '1975',
#  '2751',
#  '588',
#  '2041',
#  '2501',
#  '3410',
#  '1477',
#  '627',
#  '5577',
#  '1807',
#  '4512',
#  '3220',
#  '4497',
#  '1515',
#  '5462',
#  '1389',
#  '5757',
#  '5740',
#  '2777',
#  '629',
#  '5322',
#  '3545',
#  '3867',
#  '5432',
#  '151',
#  '3527',
#  '4192',
#  '3378',
#  '2951',
#  '2340',
#  '1680',
#  '1460',
#  '3456',
#  '5350',
#  '2975',
#  '2271',
#  '5030',
#  '4184',
#  '2612',
#  '2232',
#  '448',
#  '3190',
#  '2919',
#  '4464',
#  '4271',
#  '3416',
#  '3380',
#  '4201',
#  '3362',
#  '2897',
#  '625',
#  '3977',
#  '662',
#  '5688',
#  '5493',
#  '5404',
#  '4609',
#  '4896',
#  '731',
#  '3216',
#  '297',
#  '3760',
#  '2454',
#  '3200',
#  '5545',
#  '5168',
#  '2007',
#  '552',
#  '5166',
#  '2507',
#  '855',
#  '3588',
#  '4799',
#  '4197',
#  '3392',
#  '2956',
#  '5430',
#  '5656',
#  '4097',
#  '5689',
#  '5254',
#  '4813',
#  '2485',
#  '192',
#  '4858',
#  '4613',
#  '5684',
#  '2256',
#  '4768',
#  '3723',
#  '4262',
#  '4766',
#  '1039',
#  '1041',
#  '4255',
#  '1390',
#  '633',
#  '5767',
#  '5412',
#  '4200',
#  '2817',
#  '3491',
#  '2254',
#  '2610',
#  '1341',
#  '1845',
#  '3656',
#  '2879',
#  '5797',
#  '3774',
#  '4240',
#  '4934',
#  '5401',
#  '5605',
#  '1972',
#  '239',
#  '197',
#  '2844',
#  '30',
#  '4644',
#  '4994',
#  '5331',
#  '4076',
#  '914',
#  '4809',
#  '2802',
#  '4579',
#  '2354',
#  '5302',
#  '112',
#  '2393',
#  '4199',
#  '669',
#  '3882',
#  '4433',
#  '4443',
#  '3556',
#  '1609',
#  '2811',
#  '4077',
#  '3992',
#  '4063',
#  '2067',
#  '607',
#  '3823',
#  '619',
#  '4254',
#  '5160',
#  '3993',
#  '2706',
#  '2298',
#  '5136',
#  '5529',
#  '2795',
#  '3486',
#  '1340',
#  '3551',
#  '5563',
#  '3402',
#  '4131',
#  '2074',
#  '596',
#  '3832',
#  '5266',
#  '5431',
#  '2204',
#  '2608',
#  '5144',
#  '5206',
#  '1411',
#  '3968',
#  '4146',
#  '2683',
#  '2918',
#  '569',
#  '5351',
#  '2658',
#  '5410',
#  '58',
#  '935',
#  '5733',
#  '3032',
#  '5154',
#  '2864',
#  '306',
#  '3016',
#  '3901',
#  '4581',
#  '3985',
#  '4256',
#  '1181',
#  '5657',
#  '2869',
#  '3305',
#  '5165',
#  '4005',
#  '3989',
#  '2102',
#  '4454',
#  '3583',
#  '3325',
#  '2121',
#  '4445',
#  '647',
#  '885',
#  '2512',
#  '5703',
#  '5434',
#  '5509',
#  '4803',
#  '2910',
#  '3980',
#  '4582',
#  '4770',
#  '4651',
#  '5692',
#  '5489',
#  '4459',
#  '2973',
#  '5515',
#  '3100',
#  '1719',
#  '648',
#  '4992',
#  '889',
#  '792',
#  '4633',
#  '4072',
#  '4182',
#  '3994',
#  '2057',
#  '679',
#  '2377',
#  '562',
#  '4529',
#  '4461',
#  '742',
#  '4656',
#  '4108',
#  '4619',
#  '1023',
#  '3172',
#  '3611',
#  '2355',
#  '5480',
#  '650',
#  '3266',
#  '5458',
#  '4648',
#  '4447',
#  '3945',
#  '4829',
#  '5389',
#  '5442',
#  '620',
#  '5169',
#  '5765',
#  '2423',
#  '4634',
#  '1331',
#  '5385',
#  '5704',
#  '200',
#  '3960',
#  '857',
#  '4188',
#  '3360',
#  '331',
#  '3511',
#  '3569',
#  '4450',
#  '3570',
#  '4465',
#  '2089',
#  '4639',
#  '3547',
#  '5298',
#  '4800',
#  '2110',
#  '4106',
#  '750',
#  '2344',
#  '2793',
#  '3285',
#  '382',
#  '4291',
#  '3566',
#  '3087',
#  '5500',
#  '29',
#  '2462',
#  '3856',
#  '3554',
#  '4938',
#  '5243',
#  '3245',
#  '1159',
#  '5409',
#  '524',
#  '2820',
#  '1297',
#  '4242',
#  '4650',
#  '2320',
#  '3732',
#  '63',
#  '4056',
#  '2534',
#  '4365',
#  '2509',
#  '1188',
#  '5503',
#  '243',
#  '5610',
#  '5260',
#  '1249',
#  '3881',
#  '4578',
#  '772',
#  '5010',
#  '3139',
#  '589',
#  '3675',
#  '2843',
#  '5768',
#  '4805',
#  '2142',
#  '2056',
#  '4220',
#  '940',
#  '1381',
#  '4069',
#  '3127',
#  '1732',
#  '806',
#  '5609',
#  '4645',
#  '2799',
#  '2072',
#  '1867',
#  '1581',
#  '2723',
#  '1730',
#  '32',
#  '3073',
#  '3803',
#  '2624',
#  '4202',
#  '4099',
#  '4361',
#  '3808',
#  '1752',
#  '3420',
#  '1064',
#  '4758',
#  '1141',
#  '3618',
#  '126',
#  '3567',
#  '1855',
#  '4696',
#  '608',
#  '5416',
#  '3637',
#  '4750',
#  '1626',
#  '2633',
#  '383',
#  '3987',
#  '2042',
#  '846',
#  '2555',
#  '3824',
#  '5174',
#  '5613',
#  '4354',
#  '4705',
#  '5336',
#  '161',
#  '3103',
#  '1458',
#  '3557',
#  '417',
#  '3765',
#  '3700',
#  '3525',
#  '4021',
#  '225',
#  '1034',
#  '847',
#  '3423',
#  '4213',
#  '5345',
#  '4133',
#  '5391',
#  '4734',
#  '4641',
#  '2192',
#  '682',
#  '5769',
#  '2234',
#  '1042',
#  '5121',
#  '1832',
#  '5250',
#  '3421',
#  '1324',
#  '2168',
#  '2233',
#  '57',
#  '936',
#  '64',
#  '4595',
#  '1355',
#  '4907',
#  '4058',
#  '4162',
#  '4577',
#  '2911',
#  '1666',
#  '3369',
#  '1231',
#  '1755',
#  '1841',
#  '5580',
#  '2516',
#  '5478',
#  '1449',
#  '5506',
#  '3247',
#  '2572',
#  '4198',
#  '3558',
#  '2451',
#  '4463',
#  '1964',
#  '2618',
#  '2807',
#  '4989',
#  '3750',
#  '2562',
#  '3024',
#  '2432',
#  '4326',
#  '3783',
#  '982',
#  '3187',
#  '3241',
#  '5632',
#  '1487',
#  '1820',
#  '1943',
#  '4731',
#  '867',
#  '590',
#  '53',
#  '2916',
#  '3374',
#  '3520',
#  '2023',
#  '1901',
#  '4446',
#  '1368',
#  '1940',
#  '4130',
#  '4573',
#  '3563',
#  '3384',
#  '2601',
#  '4985',
#  '3186',
#  '2883',
#  '1753',
#  '3686',
#  '3818',
#  '5246',
#  '5109',
#  '3935',
#  '1026',
#  '2286',
#  '3449',
#  '3705',
#  '2411',
#  '459',
#  '5252',
#  '72',
#  '5694',
#  '3179',
#  '278',
#  '5690',
#  '911',
#  '2929',
#  '2934',
#  '3816',
#  '1893',
#  '2330',
#  '1683',
#  '14',
#  '2003',
#  '3029',
#  '2038',
#  '1329',
#  '738',
#  '1437',
#  '1413',
#  '2488',
#  '2514',
#  '1677',
#  '1834',
#  '5761',
#  '2508',
#  '1133',
#  '3090',
#  '1733',
#  '3215',
#  '2598',
#  '5715',
#  '514',
#  '1894',
#  '5099',
#  '3093',
#  '1836',
#  '1968',
#  '477',
#  '101',
#  '2162',
#  '3922',
#  '4453',
#  '2500',
#  '3018',
#  '1391',
#  '1567',
#  '5736',
#  '2115',
#  '691',
#  '3080',
#  '5365',
#  '4670',
#  '1373',
#  '3258',
#  '4965',
#  '3089',
#  '3182',
#  '4640',
#  '4122',
#  '5069',
#  '1480',
#  '4241',
#  '5164',
#  '3908',
#  '1583',
#  '2694',
#  '3988',
#  '3393',
#  '4539',
#  '4427',
#  '3272',
#  '74',
#  '2465',
#  '2223',
#  '3664',
#  '4238',
#  '3524',
#  '59',
#  '3916',
#  '1723',
#  '4458',
#  '365',
#  '4673',
#  '5587',
#  '5618',
#  '3896',
#  '2806',
#  '1455',
#  '5142',
#  '314',
#  '5749',
#  '1157',
#  '2709',
#  '3000',
#  '258',
#  '3195',
#  '3767',
#  '2560',
#  '5649',
#  '1176',
#  '1486',
#  '5373',
#  '3308',
#  '3785',
#  '2621',
#  '1664',
#  '5362',
#  '3829',
#  '2231',
#  '3931',
#  '5695',
#  '2113',
#  '696',
#  '4678',
#  '1016',
#  '2390',
#  '1376',
#  '4970',
#  '824',
#  '1589',
#  '3388',
#  '2741',
#  '3078',
#  '578',
#  '1319',
#  '4066',
#  '2760',
#  '1946',
#  '1965',
#  '3231',
#  '2595',
#  '3528',
#  '78',
#  '2464',
#  '5173',
#  '233',
#  '2085',
#  '2227',
#  '320',
#  '4746',
#  '1553',
#  '1360',
#  '2047',
#  '2657',
#  '3323',
#  '3561',
#  '2662',
#  '67',
#  '4908',
#  '3555',
#  '3105',
#  '5697',
#  '2687',
#  '1462',
#  '2164',
#  '3734',
#  '1442',
#  '1015',
#  '740',
#  '4905',
#  '2728',
#  '3184',
#  '3635',
#  '1550',
#  '3106',
#  '2529',
#  '726',
#  '5508',
#  '2417',
#  '922',
#  '2653',
#  '5125',
#  '4294',
#  '1571',
#  '3478',
#  '3845',
#  '1530',
#  '95',
#  '2853',
#  '876',
#  '3712',
#  '894',
#  '4569',
#  '3756',
#  '2686',
#  '4110',
#  '3502',
#  '2743',
#  '1876',
#  '1522',
#  '397',
#  '3344',
#  '5153',
#  '5785',
#  '3592',
#  '1051',
#  '3161',
#  '3235',
#  '5760',
#  '912',
#  '3814',
#  '4878',
#  '789',
#  '2925',
#  '4971',
#  '3595',
#  '3749',
#  '5495',
#  '2620',
#  '2375',
#  '4457',
#  '416',
#  '4553',
#  '3471',
#  '5239',
#  '2034',
#  '214',
#  '2080',
#  '3804',
#  '5484',
#  '5748',
#  '4030',
#  '2947',
#  '5741',
#  '4744',
#  '2964',
#  '66',
#  '515',
#  '4336',
#  '5498',
#  '1250',
#  '3193',
#  '2374',
#  '4629',
#  '4679',
#  '5617',
#  '3254',
#  '4016',
#  '2166',
#  '3175',
#  '3020',
#  '3737',
#  '196',
#  '2600',
#  '4541',
#  '2913',
#  '337',
#  '2888',
#  '4037',
#  '358',
#  '1425',
#  '1045',
#  '5536',
#  '2810',
#  '4224',
#  '2596',
#  '1326',
#  '3347',
#  '2848',
#  '4967',
#  '4290',
#  '5505',
#  '283',
#  '3905',
#  '2027',
#  '3444',
#  '4061',
#  '3954',
#  '3112',
#  '2201',
#  '3562',
#  '1184',
#  '1847',
#  '3275',
#  '2030',
#  '1388',
#  '1731',
#  '2246',
#  '3834',
#  '1418',
#  '1830',
#  '918',
#  '4642',
#  '2952',
#  '2275',
#  '3498',
#  '5744',
#  '1646',
#  '3632',
#  '328',
#  '5098',
#  '1431',
#  '4616',
#  '2805',
#  '3243',
#  '3614',
#  '4883',
#  '2127',
#  '5021',
#  '3244',
#  '3552',
#  '3796',
#  '4174',
#  '739',
#  '2946',
#  '2949',
#  '1276',
#  '428',
#  '1831',
#  '632',
#  '5650',
#  '4460',
#  '1582',
#  '1395',
#  '2240',
#  '3615',
#  '1482',
#  '2422',
#  '2415',
#  '1287',
#  '3919',
#  '3407',
#  '5604',
#  '3600',
#  '5008',
#  '176',
#  '2505',
#  '4468',
#  '4059',
#  '5696',
#  '4612',
#  '4797',
#  '3719',
#  '2244',
#  '2264',
#  '1691',
#  '2716',
#  '2613',
#  '2599',
#  '1200',
#  '4239',
#  '4921',
#  '5663',
#  '4000',
#  '2652',
#  '3169',
#  '3160',
#  '1593',
#  '1441',
#  '3786',
#  '1375',
#  '5175',
#  '3934',
#  '5306',
#  '119',
#  '2440',
#  '4243',
#  '2950',
#  '2260',
#  '2585',
#  '2368',
#  '3864',
#  '4704',
#  '5181',
#  '2496',
#  '4854',
#  '553',
#  '2923',
#  '2671',
#  '2773',
#  '5455',
#  '5456',
#  '3276',
#  '1003',
#  '2213',
#  '2745',
#  '191',
#  '148',
#  '37',
#  '2735',
#  '5291',
#  '4017',
#  '609',
#  '2644',
#  '3379',
#  '1351',
#  '3171',
#  '4903',
#  '301',
#  '639',
#  '1342',
#  '1447',
#  '557',
#  '780',
#  '948',
#  '1745',
#  ...]

# %%
podcast_ids.columns = ['podcast_id']

# %%
pd.concat([sim_df, podcast_ids], axis = 1)
# Out:
#         id  similarity  podcast_id
# 0     1634    1.000000       16392
# 1     2904    0.820921       18489
# 2     3862    0.809803       12350
# 3     1804    0.803452       12351
# 4     4191    0.800901       12352
# 5     1036    0.796088       12355
# 6     2278    0.795028       16396
# 7     4507    0.788274       16399
# 8        7    0.782280       12357
# 9     3581    0.780547       12359
# 10    3533    0.769447       12361
# 11    5425    0.764824       16403
# 12    3364    0.764318       16404
# 13    5347    0.761875       18490
# 14    5130    0.761658       12363
# 15     891    0.755901       12365
# 16    2310    0.751250       12366
# 17    2498    0.749813       12385
# 18     475    0.747695       16409
# 19    1052    0.732810       12369
# 20    4285    0.727887       12370
# 21    4081    0.727486       12371
# 22    1172    0.727138       12372
# 23    1971    0.726095       12373
# 24    3518    0.724894       16411
# 25    1518    0.715841       16426
# 26    5636    0.714921       12375
# 27    1628    0.713104       12376
# 28    5311    0.710408       12377
# 29     916    0.709945       16429
# ...    ...         ...         ...
# 5774  3055   -0.065377       18449
# 5775   380   -0.066276       18456
# 5776  3811   -0.066889       18457
# 5777  5137   -0.069034       18458
# 5778  4272   -0.072539       18459
# 5779   961   -0.072559       18460
# 5780   817   -0.075309       18487
# 5781   250   -0.075333       18462
# 5782   363   -0.083181       18463
# 5783  1243   -0.083597       18465
# 5784  2149   -0.084335       18466
# 5785  4166   -0.086502       18467
# 5786    96   -0.096401       18468
# 5787  3683   -0.098170       18469
# 5788  5449   -0.098427       18470
# 5789   400   -0.103201       18471
# 5790   777   -0.107328       18472
# 5791   933   -0.108663       18473
# 5792  3996   -0.109167       18492
# 5793   973   -0.112947       18493
# 5794  4540   -0.117425       18495
# 5795  3348   -0.123906       18496
# 5796   121   -0.144254       18497
# 5797   987   -0.148772       18498
# 5798  4312   -0.154272       18499
# 5799  4830   -0.175458       18506
# 5800  2243   -0.177660       18507
# 5801  1592   -0.181881       18509
# 5802  4818   -0.182556       18510
# 5803  1244   -0.238417       18511
#
# [5804 rows x 3 columns]

# %%
pd.concat([sim_df, podcast_ids])
# Out:
#          id  similarity
# 0      1634    1.000000
# 1      2904    0.820921
# 2      3862    0.809803
# 3      1804    0.803452
# 4      4191    0.800901
# 5      1036    0.796088
# 6      2278    0.795028
# 7      4507    0.788274
# 8         7    0.782280
# 9      3581    0.780547
# 10     3533    0.769447
# 11     5425    0.764824
# 12     3364    0.764318
# 13     5347    0.761875
# 14     5130    0.761658
# 15      891    0.755901
# 16     2310    0.751250
# 17     2498    0.749813
# 18      475    0.747695
# 19     1052    0.732810
# 20     4285    0.727887
# 21     4081    0.727486
# 22     1172    0.727138
# 23     1971    0.726095
# 24     3518    0.724894
# 25     1518    0.715841
# 26     5636    0.714921
# 27     1628    0.713104
# 28     5311    0.710408
# 29      916    0.709945
# ...     ...         ...
# 5774  18449         NaN
# 5775  18456         NaN
# 5776  18457         NaN
# 5777  18458         NaN
# 5778  18459         NaN
# 5779  18460         NaN
# 5780  18487         NaN
# 5781  18462         NaN
# 5782  18463         NaN
# 5783  18465         NaN
# 5784  18466         NaN
# 5785  18467         NaN
# 5786  18468         NaN
# 5787  18469         NaN
# 5788  18470         NaN
# 5789  18471         NaN
# 5790  18472         NaN
# 5791  18473         NaN
# 5792  18492         NaN
# 5793  18493         NaN
# 5794  18495         NaN
# 5795  18496         NaN
# 5796  18497         NaN
# 5797  18498         NaN
# 5798  18499         NaN
# 5799  18506         NaN
# 5800  18507         NaN
# 5801  18509         NaN
# 5802  18510         NaN
# 5803  18511         NaN
#
# [11608 rows x 2 columns]

# %%
podcast_data.iloc[match_ids]
# Out:
#          id language                                               text
# 1634  17233  English  [vote, favorit, polit, itun, listen, stephen, ...
# 2904  15427  English  [cover, georgia, amp, southern, polit, like, k...
# 3862  16512  English  [recent, appear, newshour, polit, analyst, col...
# 1804  16522  English  [pennsylvania, news, opinion, pennliv, patriot...
# 4191  18296  English  [spin, polit, rick, pearson, wgn, anoth, big, ...
# 1036  16962  English  [doc, holliday, rock, split, polit, inspir, fr...
# 2278  17540  English  [join, host, lynn, sebourn, discuss, grassroot...
# 4507  16617  English  [weekli, convers, polit, ken, rudin, mpr, news...
# 7     16399  English  [iowa, polit, weekli, news, analysi, aim, recr...
# 3581  16139  English  [weekli, read, magazin, essay, radic, measur, ...
# 3533  18251  English  [weekli, standard, podcast, deliv, uniqu, anal...
# 5425  15305  English  [provoc, uptotheminut, aliv, witti, kcrw, week...
# 3364  15878  English  [launch, nation, collabor, blog, progress, mom...
# 5347  15061  English  [pickl, barrel, place, talk, event, take, plac...
# 5130  14360  English  [face, nation, one, longestrun, news, program,...
# 891   13312  English  [cspan, provid, viewer, rang, public, polici, ...
# 2310  14757  English  [fear, extremist, rightw, hardcharg, guntot, o...
# 2498  17672  English  [coupl, siriusxm, radio, host, prove, need, li...
# 475   12868  English  [bard, logic, show, peopl, show, mission, faci...
# 1052  13466  English  [progress, talkshow, host, carl, wolfson, brin...
# 4285  15096  English  [talk, program, capit, griffin, strength, inve...
# 4081  17577  English  [expos, truth, global, warm, media, bia, liber...
# 1172  13597  English  [weekli, dose, inyourfac, satir, ninja, jeff, ...
# 1971  17396  English  [coupl, guy, pittsburgh, orlando, discuss, nat...
# 3518  18229  English  [irrever, modern, polit, deserv, chri, spangl,...
# 1518  13970  English  [day, news, magazin, show, deliv, surpris, tak...
# 5636  16005  English  [sinc, bring, histor, context, polit, today, t...
# 1628  17231  English  [audio, program, doubl, x, slate, blog, found,...
# 5311  14941  English  [admit, idea, talk, cari, sean, attempt, discu...
# 916   16906  English  [river, river, iowa, public, radio, talk, prog...
# ...     ...      ...                                                ...
# 3055  17947  English  [toyota, perform, garag, host, manni, costa, d...
# 380   12763  English  [daili, best, austin, morn, news, show, mark, ...
# 3811  16439  English  [join, happygolucki, unlucki, often, hero, bra...
# 5137  14339  English  [ancient, faith, radio, pleas, present, conver...
# 4272  12946  English  [catch, weekli, report, devot, beef, industri,...
# 961   16931  English  [monthli, webonli, featur, podcast, perform, n...
# 817   13239  English  [rambl, rant, uk, lead, xbox, fansit, expans, ...
# 250   16664  English  [listen, pricey, breakfast, townsvil, pricey, ...
# 363   12747  English  [audio, homili, record, fr, paul, yi, cathol, ...
# 1243  17078  English  [altern, indi, music, best, scotland, unsign, ...
# 2149  17483  English  [sunk, afin, session, qualiti, biweekli, deep,...
# 4166  18149  English  [host, nikolai, victoria, countri, hour, count...
# 96    12465  English  [weekli, mix, intern, guest, mix, second, week...
# 3683  16271  English  [david, price, jason, wood, book, stuff, ocloc...
# 5449  15423  English  [assort, stori, japan, jukebox, japan, jukebox...
# 400   12787  English  [daili, program, hmong, health, famili, amp, s...
# 777   13192  English  [bread, life, fellowship, privat, associ, chri...
# 933   13498  English  [invit, subscrib, cathol, cardin, reflect, reg...
# 3996  16948  English  [sampl, select, collect, live, grate, dead, co...
# 973   16934  English  [sound, histor, jim, sullivan, programm, give,...
# 4540  12925  English  [heal, presenc, other, give, strength, give, h...
# 3348  18076  English  [everi, week, ucap, gang, gather, talk, thing,...
# 121   12580  English  [ancient, faith, radio, pleas, present, press,...
# 987   13499  English  [clear, concis, cathol, teach, will, get, coac...
# 4312  13322  English  [music, media, updat, weekli, choir, church, r...
# 4830  13334  English  [call, cathol, live, mondayfriday, pm, produc,...
# 2243  14694  English  [thought, reflect, orthodox, theolog, life, fr...
# 1592  14055  English  [join, fr, timothi, gallagh, show, host, kri, ...
# 4818  13297  English  [fr, dave, dwyer, csp, barbara, wheelerbrid, a...
# 1244  17079  English  [listen, previou, show, scotland, talk, scotla...
#
# [5804 rows x 3 columns]

# %%
similarity_df = pd.DataFrame(columns=['search_id', 'match_id', 'similarity'])

# %%
for row_id in tqdm.tqdm(range(podcast_data.shape[0])):
    search_id = int(podcast_data.iloc[row_id]['id'])
    search_vec = lsi[corpus[row_id]]
    sims = index[search_vec]
    sims = sorted(enumerate(sims), key=lambda item: -item[1])
    
    # remove self match (should be first)
    for i, (id, sim) in enumerate(sims):
        if id == row_id:
            del sims[i]
            break
    
    # get match ids and similarities
    match_id = [podcast_data.iloc[match[0]]['id'] for match in sims]
    similarity = [match[1] for match in sims]
    
    similarity_df = similarity_df.append(pd.DataFrame({'search_id' : [[search_id] * len(match_id)],
                                                      'match_id' : [match_id],
                                                      'similarity' : [similarity]}))

# %%
similarity_df.to_pickle('gensim/similarity_df.pkl')

# %%
print index
# Out:
# MatrixSimilarity<5804 docs, 100 features>
